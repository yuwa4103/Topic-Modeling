# %% [markdown]
# # **Look Through the Amazon product metadata and extracts ASINs**

# %%
import pandas as pd
import pickle
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
path = 'drive/My Drive/Colab Notebooks/APRD6343_NEW/meta_Clothing_Shoes_and_Jewelry.json'
loadedjson = open(path, 'r')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Extracting ASINS by brand
# only going to print our count every 100k
count = 0
# initiate dictionaries before we use
allproducts = {}
# Each line here is a product and its metadata
for aline in loadedjson:
  count += 1
  if count % 100000 == 0:
    print(count)
  aproduct = eval(aline)
# Making a dictionary entry with the ASIN of the product as the key
  allproducts[aproduct['asin']] = aproduct
# Out:
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000

# %%
len(allproducts)
# Out:
# 1503384

# %%
# Explore the product data to see what categories are commom in the data
# Find a list of product ids
allcategories = {}
count = 0

for aproduct in allproducts:
   count += 1
   if count % 100000 == 0:
     print (count/len(allproducts))

# Setting a dict up with just one product
   aproduct = allproducts[aproduct]
# Creating a dictionary entry for each product category also counting the occurances of each category
   if 'categories' in aproduct:
      for categories in aproduct['categories']:
       for acategory in categories:
        if acategory in allcategories:
          allcategories[acategory] += 1
        if acategory not in allcategories:
          allcategories[acategory] = 1
# Out:
# 0.06651660520532346
# 0.13303321041064692
# 0.19954981561597038
# 0.26606642082129384
# 0.33258302602661727
# 0.39909963123194075
# 0.4656162364372642
# 0.5321328416425877
# 0.5986494468479111
# 0.6651660520532345
# 0.7316826572585581
# 0.7981992624638815
# 0.8647158676692049
# 0.9312324728745284
# 0.9977490780798518

# %%
allcategories['adidas']
# Out:
# 8645

# %%
sortedlist = []
for acategory in allcategories:
  sortedlist.append((allcategories[acategory],acategory)) 
sortedlist = sorted (sortedlist, reverse=True)
for item in range (200,300):
  print(sortedlist[item])
# Out:
# (4988, 'Columbia')
# (4895, 'Nautica')
# (4849, 'Boutique Designer Jewelry')
# (4705, 'Cold Weather Gloves')
# (4701, 'Sports Sunglasses')
# (4604, 'O')
# (4594, 'Suits & Sport Coats')
# (4593, 'Steve Madden')
# (4562, 'Military')
# (4468, 'Rain')
# (4462, 'Watch Accessories')
# (4457, 'Work & Safety')
# (4398, 'Wedding Party Gifts')
# (4385, 'W')
# (4243, 'Snow Boots')
# (4237, 'Nightgowns & Sleepshirts')
# (4185, 'Brooches & Pins')
# (4181, 'Lucky Brand')
# (4171, 'Engagement Rings')
# (4100, 'Barbells')
# (4072, 'Boxer Briefs')
# (4037, 'Vests')
# (4036, 'Kenneth Cole REACTION')
# (4027, 'Fitness & Cross-Training')
# (4014, 'Heart-Shaped Jewelry')
# (3980, 'Exercise & Fitness')
# (3974, 'Charms & Charm Bracelets')
# (3965, 'Motorcycle')
# (3955, 'I')
# (3953, 'Statement')
# (3904, 'Kenneth Cole New York')
# (3899, 'Timberland')
# (3848, 'Merrell')
# (3812, "Kids' Backpacks")
# (3790, 'Travel Accessories')
# (3760, 'Hiking Shoes')
# (3725, 'Messenger Bags')
# (3678, 'Western')
# (3657, 'FOSSIL')
# (3633, 'Tommy Hilfiger')
# (3633, 'Footies & Rompers')
# (3604, 'Medical')
# (3598, 'Jessica Simpson')
# (3597, 'Work Utility & Safety')
# (3586, 'Roxy')
# (3575, 'Masks')
# (3569, 'Industrial & Construction')
# (3533, 'Wigs')
# (3520, 'Sport Sandals')
# (3515, 'Lingerie')
# (3513, 'U')
# (3502, 'Dickies')
# (3500, 'Rockport')
# (3488, 'Tights')
# (3473, 'Rain Footwear')
# (3452, 'Contemporary Designer Jewelry')
# (3435, 'Lightweight Jackets')
# (3419, 'Jewelry Boxes')
# (3419, 'Hoop')
# (3407, 'Outerwear & Coats')
# (3389, 'Trail Running')
# (3355, 'Carhartt')
# (3350, 'Night Out & Special Occasion')
# (3346, 'Tunics')
# (3319, 'Hiking Boots')
# (3272, 'Bustiers & Corsets')
# (3263, 'Suits & Blazers')
# (3258, 'Tank Tops')
# (3253, 'Pants & Capris')
# (3181, 'Soccer')
# (3145, 'Basketball')
# (3135, 'Link')
# (3116, 'Shoe Care & Accessories')
# (3109, 'Chains')
# (3105, 'Riding')
# (3102, 'Shearling')
# (3054, 'Keen')
# (3010, 'Leather & Faux Leather')
# (2988, 'Dockers')
# (2975, 'Stride Rite')
# (2969, 'Cover-Ups')
# (2966, 'Seiko Watches')
# (2936, 'Dress Shirts')
# (2921, 'Active Hoodies')
# (2917, 'Skullies & Beanies')
# (2914, 'Naturalizer')
# (2914, 'Luxury Watches')
# (2908, 'Denim')
# (2907, 'Golf')
# (2870, 'COACH')
# (2867, 'GUESS')
# (2851, 'Button-Down Shirts')
# (2851, 'Betsey Johnson')
# (2829, 'Quiksilver')
# (2829, 'Q')
# (2827, 'Sports Bras')
# (2825, 'Blazers')
# (2732, 'Hosiery')
# (2720, 'Sun Hats')
# (2698, 'Lingerie Sets')

# %%
for i in range(len(sortedlist)):
  if sortedlist[i][1] == 'adidas':
    print (sortedlist[i])
# Out:
# (8645, 'adidas')

# %%
alladidasasins = set()
count = 0
for areview in allproducts:
  theproduct = allproducts[areview]
  count += 1
  if count % 100000 == 0:
    print (count/1503384)
  for categories in theproduct['categories']:
    for acategory in categories:
      if 'adidas' in acategory.lower():
        alladidasasins.add(theproduct['asin'])

print(len(alladidasasins))
# Out:
# 0.06651660520532346
# 0.13303321041064692
# 0.19954981561597038
# 0.26606642082129384
# 0.33258302602661727
# 0.39909963123194075
# 0.4656162364372642
# 0.5321328416425877
# 0.5986494468479111
# 0.6651660520532345
# 0.7316826572585581
# 0.7981992624638815
# 0.8647158676692049
# 0.9312324728745284
# 0.9977490780798518
# 9457

# %%
outputfile = open('drive/My Drive/Colab Notebooks/APRD6343_NEW/adidasasins1.txt','w')
outputfile.write(','.join(alladidasasins))
outputfile.close()

# %% [markdown]
# # **By Sales Rank**

# %%
## We choose a set here becuase we don't wnat duplicates
# alladidasasins = set()
alladidasasins = {}
count = 0
from time import sleep

for areview in allproducts:
  count += 1
  if count % 100000 == 0:
    print(count/1503384)

  theproduct = allproducts[areview]
  # alladidasasins[areview] ={}
  if 'salesRank' in theproduct:
    for categories in theproduct['categories']:
      for acategory in categories:
        if 'adidas' in acategory.lower():
          for acategory in theproduct['salesRank']:
            alladidasasins[areview] = theproduct['salesRank'][acategory]
            # print(areview, acategory, theproduct['salesRank'][acategory])

# alladidasasins.add(theproduct['asin'])
print(len(alladidasasins))
# Out:
# 0.06651660520532346
# 0.13303321041064692
# 0.19954981561597038
# 0.26606642082129384
# 0.33258302602661727
# 0.39909963123194075
# 0.4656162364372642
# 0.5321328416425877
# 0.5986494468479111
# 0.6651660520532345
# 0.7316826572585581
# 0.7981992624638815
# 0.8647158676692049
# 0.9312324728745284
# 0.9977490780798518
# 9218

# %%
unsortedsalesrank = []
for aproduct in alladidasasins:
  unsortedsalesrank.append((alladidasasins[aproduct], aproduct))

unsortedsalesrank[0]
# Out:
# (435275, 'B000071JZK')

# %%
# sort salesRank
sortedsalesrank= sorted(unsortedsalesrank)
sortedsalesrank[0:10]
# Out:
# [(228, 'B003NX87U6'),
#  (228, 'B003NX8C0Q'),
#  (228, 'B003NX8C6K'),
#  (228, 'B003NX8C7E'),
#  (228, 'B003NX8CBA'),
#  (228, 'B003NX8CEC'),
#  (228, 'B003NX8CIS'),
#  (228, 'B003NX8CKG'),
#  (228, 'B003NX8CME'),
#  (228, 'B003NX8COM')]

# %%
# plot
sortedsalesrank= sorted(unsortedsalesrank)
top100products = sortedsalesrank[0:100]

salesrank = []
for aproduct in sortedsalesrank:
  salesrank.append(aproduct[0])

print(salesrank[0:10])
# Out:
# [228, 228, 228, 228, 228, 228, 228, 228, 228, 228]

# %%
import numpy as np
import seaborn as sns
ax = sns.distplot(salesrank[0:100])

# %%
outputfile = open('drive/My Drive/Colab Notebooks/APRD6343_NEW/adidasasins2.txt','w')
outputfile.write(','.join(alladidasasins))
outputfile.close()

# %% [markdown]
# # **Extracts the review for adidas brand**

# %%
import pickle
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
path = 'drive/My Drive/Colab Notebooks/APRD6343_NEW/reviews_Clothing_Shoes_and_Jewelry.json'
loadedjson = open(path, 'r')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Step 2 - Phrsing the review data
#Loading the review data into a dictionary
count = 0
allreviews = {}
for aline in loadedjson:
  count += 1
  if count%100000 == 0:
    print(count)
  areview = eval(aline)
  allreviews[count] = areview

print(len(allreviews))
# Out:
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# 3300000
# 3400000
# 3500000
# 3600000
# 3700000
# 3800000
# 3900000
# 4000000
# 4100000
# 4200000
# 4300000
# 4400000
# 4500000
# 4600000
# 4700000
# 4800000
# 4900000
# 5000000
# 5100000
# 5200000
# 5300000
# 5400000
# 5500000
# 5600000
# 5700000
# 5748920

# %%
#pick out the reviews that correspond to the matching ASINs
from time import sleep

alladidasasins = []
for data in open('drive/My Drive/Colab Notebooks/APRD6343_NEW/adidasasins1.txt','r'):
 asins = data.split(',')
 for anasin in asins:
   alladidasasins.append(anasin)

print(alladidasasins)
# Out:
# ['B003V5WKL8', 'B005ET87UC', 'B000214PQM', 'B000NUQCTA', 'B006Z8H2G6', 'B006C1F5F6', 'B004JXW1NI', 'B009IR0EFC', 'B002F00KC6', 'B007C6RC7E', 'B007XCYXQU', 'B00213L06M', 'B000LS51IW', 'B007P6EWYM', 'B00EP082PQ', 'B002F005R6', 'B00KCSX340', 'B00GXR9CQW', 'B004IZLAU2', 'B004JXWXCW', 'B0012VPCOK', 'B003LR0SKQ', 'B000QYEK9W', 'B0058VTPNY', 'B001C8WF8E', 'B003V4C4YM', 'B00F0UJA0G', 'B002SHTK54', 'B0012R4RI6', 'B004L638Z8', 'B000LF645E', 'B00D60KOM0', 'B002Y55YIC', 'B002ZG8H2K', 'B00FKXHY9C', 'B0012VFULK', 'B00ASRN6RO', 'B00J83JLD2', 'B002PMUZ6K', 'B0010B3884', 'B004JXWMV4', 'B00107WUG4', 'B0058XO30C', 'B007WQNQ8I', 'B00E3ERW6Y', 'B004RKJ9EW', 'B008KO58VO', 'B009KTIRIY', 'B000M3CUF8', 'B006WV0PW4', 'B004JXWLGK', 'B000QJBPUO', 'B0012V7NHY', 'B001I459J4', 'B006OEJDS6', 'B0058W4D8U', 'B00ASRLL8A', 'B005TFE5BG', 'B001OMHYZC', 'B000CSOHA4', 'B006R8OQ6I', 'B0036R2LNI', 'B00KCSXQDI', 'B009VRB9X0', 'B007EV3Y5G', 'B00I9ICTQS', 'B009KX7T48', 'B000ENHUDI', 'B001C8YSQQ', 'B004S0TL0I', 'B00DTWIP1M', 'B00FHWFEAM', 'B00104Z1SG', 'B002FQJNOQ', 'B0044XTER4', 'B000OOJ012', 'B004FPIEX6', 'B000GHPPNY', 'B00104QMTI', 'B000M4NHUY', 'B000KO8HBK', 'B002WPYWO6', 'B003V5VZOG', 'B004JXX89O', 'B005HEUYT6', 'B004X2A16Y', 'B005EMULPS', 'B000071JZK', 'B004ON8OQ6', 'B00CE86BZE', 'B003CP459W', 'B004UB8WR8', 'B003U4VQLK', 'B001OQCD18', 'B007K7ZAS8', 'B001BJQTTK', 'B005RDQJQO', 'B00318D8QQ', 'B000PDJTEA', 'B000TRMXZ4', 'B0012SI9A2', 'B008HTQ7EO', 'B004RKJKHI', 'B005P04EBG', 'B001I44ECW', 'B00305GOI4', 'B004LZ5HYO', 'B000ZHFV8E', 'B004OMTFQK', 'B00CHUFNS0', 'B003V4BTGQ', 'B00DI7GKRY', 'B0071Q7RHA', 'B002DW9OGO', 'B002WHDDWQ', 'B000VHMAKK', 'B003U4UTNQ', 'B0047EN7K0', 'B006QXQ2ZM', 'B000W4HBMO', 'B0032U9132', 'B0014XAR0K', 'B0058W3OXU', 'B000EE5IV8', 'B008HSHV9K', 'B000W2QF82', 'B00ILOIT8C', 'B009B7U9M2', 'B0034YI38A', 'B0058YG55C', 'B005RDGEDC', 'B00213KS1U', 'B0017K819O', 'B005I7263Y', 'B007K7ZF60', 'B006RK3C16', 'B00166UJ1C', 'B004RKJ280', 'B0008F5KZM', 'B009SNOH7W', 'B00213KAQ8', 'B003V4C86Q', 'B006QXBOTG', 'B0012XIPI8', 'B008DVLTJ4', 'B007WQNK5M', 'B0031QOXGW', 'B001HZZB1K', 'B008PKM898', 'B004JXX8P8', 'B005GC67MC', 'B006CQ2E50', 'B0009C9GVI', 'B006RAN90K', 'B004MTJIVC', 'B008I7CQEK', 'B00AZNRNDO', 'B000ZHBWD2', 'B000K2MIZS', 'B00GYX6358', 'B004JXVUGC', 'B002D4W0QS', 'B004JXVP30', 'B00593T8HO', 'B0015UFM8Y', 'B005I71RS4', 'B006RAHNP2', 'B001P06J8Q', 'B00GYX6SRG', 'B004RKJJII', 'B002HOQEFM', 'B000OWKEI2', 'B008I6V4FI', 'B001I44S5U', 'B000CFL0UC', 'B001I45822', 'B006QQ0V42', 'B001OMI6BS', 'B0012XIZ5G', 'B005GC14NY', 'B007K7YSI6', 'B000O3TIO2', 'B00ATSHG0A', 'B001I44E2C', 'B000NAJ7M4', 'B00J5ILTHG', 'B0058XG9GS', 'B00B3VU3ES', 'B009RTNTZ8', 'B004YZJOJ0', 'B001931D44', 'B001HZZ264', 'B005GC2P32', 'B009EZEAUI', 'B004JXWPVQ', 'B00C6KICVG', 'B0010B3BMM', 'B0058YE860', 'B007XCYZM2', 'B0012S7Q2Y', 'B002FQJ8KA', 'B001CH7VCK', 'B007K7YNV8', 'B00139CNQG', 'B000H0252E', 'B0007YG918', 'B006WV193S', 'B006QPM9GG', 'B000VHIHQG', 'B000SNVDWS', 'B000VHO882', 'B004M6FLMU', 'B003Q6C724', 'B001I44VG6', 'B00GJ9DFLM', 'B000QXQ3AM', 'B008HTO1WY', 'B00305GB64', 'B000E1WDWS', 'B000QXRN56', 'B003VYDL1M', 'B006EP1CZM', 'B006RAJ3GY', 'B00IK3L1A2', 'B004JXWQZ6', 'B009SPIMJY', 'B00C40R462', 'B008I6I7BM', 'B0014DU80O', 'B007PBFL7O', 'B00593W6B4', 'B00AQLRZEW', 'B005HTA6OY', 'B001C8XB78', 'B00ATSXFEG', 'B0058YD9TM', 'B003PDO97E', 'B006OO4RN2', 'B000CFER84', 'B0058MD142', 'B0058YEEGY', 'B008VN43G0', 'B0058VU4Z2', 'B00DQYO6WK', 'B003V5X6M0', 'B006WWPE4C', 'B004FPHSW4', 'B005RDQOYQ', 'B000HJNLSM', 'B004FPI27Y', 'B001RTSWL2', 'B000TZUP24', 'B0025UR0JW', 'B005LBZ3P0', 'B0010AWPRU', 'B001RTSVY0', 'B0012S5TI2', 'B0048LTMH4', 'B004B9DAG2', 'B005LZSFRE', 'B002PJ55J0', 'B002I3XC16', 'B001C8Z482', 'B000R4FLUI', 'B001CGW4Z0', 'B004JXVQ7U', 'B00328GONY', 'B00E1SILKI', 'B00ABQTYLO', 'B005GC5QQA', 'B0030MIRN2', 'B006R84AWI', 'B0045Y2BLS', 'B0012VL6S6', 'B004OMVIYC', 'B007PBJLDE', 'B0058XLFEE', 'B00C6FEFV2', 'B000J3ILTU', 'B004MTHO3G', 'B000F3G6QO', 'B00AQMW2M6', 'B00DVW3HE0', 'B000J3KV8Y', 'B0070S5OO2', 'B004YZJM ...

# %%
print(len(alladidasasins))
# Out:
# 9457

# %%
adidasreviews = {}
count = 0
for areview in allreviews:
  count += 1
  if count % 100000 == 0:
    print(count/5748920)
#setting current review as a dictionary,so we can easily reference its entries 
  thereview = allreviews[areview]
  theasin = thereview['asin']
  reviewerid = thereview['reviewerID']
  if thereview['asin'] in alladidasasins:
#setting the key as sth unique, if we just did by asin,we only have one review for each asin,last one is only one being store    
    thekey = '%s.%s' % (theasin,reviewerid)
    adidasreviews[thekey] = thereview

print(len(adidasreviews))
# Out:
# 0.017394571502125616
# 0.03478914300425123
# 0.05218371450637685
# 0.06957828600850247
# 0.08697285751062808
# 0.1043674290127537
# 0.12176200051487931
# 0.13915657201700493
# 0.15655114351913055
# 0.17394571502125616
# 0.19134028652338178
# 0.2087348580255074
# 0.226129429527633
# 0.24352400102975863
# 0.2609185725318843
# 0.27831314403400986
# 0.2957077155361355
# 0.3131022870382611
# 0.33049685854038674
# 0.34789143004251233
# 0.365286001544638
# 0.38268057304676356
# 0.4000751445488892
# 0.4174697160510148
# 0.43486428755314044
# 0.452258859055266
# 0.46965343055739167
# 0.48704800205951726
# 0.5044425735616429
# 0.5218371450637685
# 0.5392317165658941
# 0.5566262880680197
# 0.5740208595701454
# 0.591415431072271
# 0.6088100025743965
# 0.6262045740765222
# 0.6435991455786478
# 0.6609937170807735
# 0.678388288582899
# 0.6957828600850247
# 0.7131774315871503
# 0.730572003089276
# 0.7479665745914015
# 0.7653611460935271
# 0.7827557175956528
# 0.8001502890977784
# 0.8175448605999039
# 0.8349394321020296
# 0.8523340036041552
# 0.8697285751062809
# 0.8871231466084064
# 0.904517718110532
# 0.9219122896126577
# 0.9393068611147833
# 0.9567014326169089
# 0.9740960041190345
# 0.9914905756211602
# 27511

# %%
#save as new json file
json.dump(adidasreviews, open('drive/My Drive/Colab Notebooks/APRD6343_NEW/adidasreviews1.json','w'))

# %%
#load
alladidasreviews = json.load(open('drive/My Drive/Colab Notebooks/APRD6343_NEW/adidasreviews1.json','r'))
#check its working or not
alladidasreviews
# Out:
# {'B000071JZK.A3SW93SXD720ER': {'asin': 'B000071JZK',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "A great shoe. Doesn't show off a lot. Really comfortable, and never out of style",
#   'reviewTime': '01 8, 2005',
#   'reviewerID': 'A3SW93SXD720ER',
#   'reviewerName': 'Average Joe "John Hancock"',
#   'summary': 'The Adidas Superstar I',
#   'unixReviewTime': 1105142400},
#  'B000071JZK.A29Y0F0ZEWAVZW': {'asin': 'B000071JZK',
#   'helpful': [1, 1],
#   'overall': 5.0,
#   'reviewText': "I have 4 pairs of these shoes and I love them to death!  They are as close to indestructable as any shoe I've ever owned.  Then you're probably asking why I have so many.  Well, the answer is that this is the only shoe I know of that comes in so many colors (I've seen at least 7 or 8 colors) and works with just about everything in your wardrobe!  Jeans, khakis, whatever- they work, and I love 'em!!!",
#   'reviewTime': '12 12, 2002',
#   'reviewerID': 'A29Y0F0ZEWAVZW',
#   'reviewerName': '"frankiepmcg"',
#   'summary': 'For anywhere, with anything...',
#   'unixReviewTime': 1039651200},
#  'B000071JZK.AOMVHELVPK1IX': {'asin': 'B000071JZK',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'These were my first pair of really nice shoes and will probably be the only tennis shoes I will ever buy. They are very versatile; I can wear them when I am out on a walk, on a run, to school, to church and they are great when I am traveling. They even fit bulky orthotics and my wide feet that other tennis shoes are not made to handle. Adidas are comfortable, stylish and the ultimate tennis shoe!',
#   'reviewTime': '04 7, 2003',
#   'reviewerID': 'AOMVHELVPK1IX',
#   'reviewerName': 'Lizzie',
#   'summary': 'Adidas: The Ultimate Tennis Shoes!',
#   'unixReviewTime': 1049673600},
#  'B000071JZK.A244AO7KQ6WWK3': {'asin': 'B000071JZK',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "The first time I saw a pair of Superstars was 8 years ago and I thought they were the coolest looking all-purpose shoes I had ever seen. I immediately went out and bought my first pair and haven't been without at least 2 styles ever since. Classic, simple, comfortable, and durable, they have never failed me whether at work (I'm a Fed Ex courier) or play. The break in period is almost non-existent and best of all, the sole wears out before the upper leather portion wears out. For the price and dependability, you cannot lose with this shoe!",
#   'reviewTime': '11 11, 2002',
#   'reviewerID': 'A244AO7KQ6WWK3',
#   'reviewerName': 'Ron',
#   'summary': 'Comfort + style = one great shoe!',
#   'unixReviewTime': 1036972800},
#  'B0000727P4.A3BGP42GLM6XSK': {'asin': 'B0000727P4',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': 'This shoe is a stylish and responsive addition to the vast adidas selection. It has very good heel support, without sacrificing flexibility. For those of you who enjoy room for your toes to &quot;breathe&quot; and curl, be sure to get them a size and a half to a size large. The only problem I found with these, was that unless tied firm and tight, your foot slides around a little bit. Overall, I highly recommend these shoes.',
#   'reviewTime': '03 18, 2003',
#   'reviewerID': 'A3BGP42GLM6XSK',
#   'reviewerName': 'Chris Lynn',
#   'summary': 'Good shoe, good price',
#   'unixReviewTime': 1047945600},
#  'B00007498E.A30OQJNGCUWYMC': {'asin': 'B00007498E',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "if ur into soccer and want cleats these are it ok so they're not the cheapest but they are the best u can find they are amazing. They're the best looking cleat i've ever seen and they are just great.",
#   'reviewTime': '12 14, 2002',
#   'reviewerID': 'A30OQJNGCUWYMC',
#   'reviewerName': '"kerchm"',
#   'summary': 'these are hot',
#   'unixReviewTime': 1039824000},
#  'B000074FCW.AHWWB5H2T2LUN': {'asin': 'B000074FCW',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "I've been playing soccer for my entire life and at last I've found a shoe that doesn't hurt my feet after a game.Very good traction , beatifull design and very original model.Thank you ADIDAS.",
#   'reviewTime': '03 23, 2003',
#   'reviewerID': 'AHWWB5H2T2LUN',
#   'reviewerName': 'Ivan Castillog',
#   'summary': 'THE BEST SHOES FOR SOCCER',
#   'unixReviewTime': 1048377600},
#  'B000074Z75.A2ISK13FGTLR1B': {'asin': 'B000074Z75',
#   'helpful': [11, 11],
#   'overall': 5.0,
#   'reviewText': 'Let me start off by saying WOW. These shoes are sooo unbelivable its not funny. The bulit in sock gives you better ankel support and the laces never come un-tied. The style of this shoe is amazing. I give who ever made this shoe a 50 out of 10. I have played ball with a pair of T-Mac 2s and it feels as if you are wearing socs. The material it is made out of must be very light. The cusioning inside the shoe is has so much comfort it feels as if you are playing ball in a pair of fluffy socks. The non-marking sole is sweet too if you want to playing on or off the court. If you are playing off court, you never scuff your shoes. These shoes are amazing!!',
#   'reviewTime': '02 23, 2003',
#   'reviewerID': 'A2ISK13FGTLR1B',
#   'reviewerName': 'Blaze Smith',
#   'summary': 'T-Mac 2s are the best basketball shoe out there',
#   'unixReviewTime': 1045958400},
#  'B000074Z75.AEJX1536BYVIC': {'asin': 'B000074Z75',
#   'helpful': [3, 5],
#   'overall': 5.0,
#   'reviewText': 'You have to definently get these shoes because they are the best shoes out there at this moment.Their nice looking, durable, and well worth [the money]. If you are looking for basketball shoes or even shoes to just wear around you must get these.',
#   'reviewTime': '03 13, 2003',
#   'reviewerID': 'AEJX1536BYVIC',
#   'reviewerName': 'Debra Nichols',
#   'summary': 'WOW',
#   'unixReviewTime': 1047513600},
#  'B000074Z75.A1I9BKJBGK34H9': {'asin': 'B000074Z75',
#   'helpful': [0, 1],
#   'overall': 5.0,
#   'reviewText': "PEOPLE,DIS PAIR OF SHOES IS DA BEST PAIR OF SHOES YOU WILL EVA BUY,I LOOK EVA SO PIMP IN EM',I BRING ALL DA LADIES TO DA COURT,AND THEY LOVE DA WAY I PLAY BASKETBALL,I REALLY RECCOMENDATIZZAL THAT YOU BUY THESE SHOES FOR RIZZAL,AND WHEN YOU DO BUY DA P.I.M.P SHOES,ALL THE LADIES WILL BE ASKIN YOU RO SHIZZAL WITH YO NIZZAL,PEACE TO THE BROTHAS IN DA HOOD WHO HAVE DA T MACS,SIGHNED,YO MAMMA.",
#   'reviewTime': '06 1, 2004',
#   'reviewerID': 'A1I9BKJBGK34H9',
#   'reviewerName': 'JOHN edwards',
#   'summary': "t mac 2's",
#   'unixReviewTime': 1086048000},
#  'B0000751WW.A32LWUHSNTWMPB': {'asin': 'B0000751WW',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "I bought a pair of these shoes (in Espresso/Creme) for walking, because I'm a college student and I do a lot of walking around on campus every day. The sales person at Foot Locker did not recommend them for walking, but I do. They're comfortable, feminine, and very nicely designed. The shoe is made of breathable leather (a must for this Texas heat!), and fits my foot very nicely. In addition, the padded insole is much more comfortable than a regular tennis shoe. And don't let the thin soles fool you - this shoe is durable!As an Adidas &quot;fan&quot;, I'd recommend this shoe simply because Adidas makes high quality, long-lasting shoes. As someone who needs comfortable shoes, I recommend this pair not only because of the quality, but also because of the comfort they offer. The fact that they're also quite cute (at least, I think so) is an added bonus. Overall, this is a great pair of shoes, and I'd recommend it to anyone who needs a sturdy and comfortable, yet stylish, pair of shoes for an active lifetsyle.",
#   'reviewTime': '09 23, 2003',
#   'reviewerID': 'A32LWUHSNTWMPB',
#   'reviewerName': 'Miriam Rouziek',
#   'summary': 'Great shoes, very comfortable',
#   'unixReviewTime': 1064275200},
#  'B00007GDIR.A3HMWAHKTOVITE': {'asin': 'B00007GDIR',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': "Don't be fooled by the picture, these shoes are actually grey, and not brown or tan.  I bought them thinking they were the latter, and I was surprised when I opened the box and saw them in the harsh light of reality.  Having said that, they are indeed fine and rare, and would probably make a handsome addition to your wardrobe.  They are part of Adidas' &quot;stitch down&quot; collection of vintage sneakers re-conceptualized in high end materials, and I don't think you can even find them anywhere else.  These particular shoes are made of corduroy, rather than the traditional samoa suede, and they have nice crepe soles.  If you have wide feet, Adidas can be somewhat tricky to size, so make sure you know your correct Adidas size (go down to your local shoe store and try on a pair of regular samoas for size) before you order.",
#   'reviewTime': '07 17, 2003',
#   'reviewerID': 'A3HMWAHKTOVITE',
#   'reviewerName': 'G. Rao "grao!!!"',
#   'summary': 'These shoes are grey, not brown.',
#   'unixReviewTime': 1058400000},
#  'B000086PVY.AUQSJDXJ0M1IE': {'asin': 'B000086PVY',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': 'Nice shoes, but lack up support might not make them last after while, but nice design and concept.  I get alot of compliments.BUT I would not order form footlocker again.  They shipped these in a bag!?  A shoe box in a bag?! By the time they got to me the box was totally crushed and not in any good condtion.  BAD BAD SHIPPING  I called footlocker and they could have cared less.',
#   'reviewTime': '09 11, 2003',
#   'reviewerID': 'AUQSJDXJ0M1IE',
#   'reviewerName': 'Steev "steevil"',
#   'summary': 'NIce shoes, might not hold up after awhile',
#   'unixReviewTime': 1063238400},
#  'B00008XNMS.A1SIG6MUBKWRN4': {'asin': 'B00008XNMS',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'so easy to order on line when it was impossible to find at a store!',
#   'reviewTime': '01 9, 2007',
#   'reviewerID': 'A1SIG6MUBKWRN4',
#   'reviewerName': 'J. Alessandrini',
#   'summary': 'easy purchase',
#   'unixReviewTime': 1168300800},
#  'B00009PO1X.A1OOIZ00E84JFJ': {'asin': 'B00009PO1X',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'My daughter plays Volleyball and is totally satisfied with her this pair of shoes.  And as her mom I am totally satisfied with the price!!!  The color is bright but goes perfectly with her team colors!!  I recommend them!',
#   'reviewTime': '01 18, 2007',
#   'reviewerID': 'A1OOIZ00E84JFJ',
#   'reviewerName': 'Amy Adams "Mom of three"',
#   'summary': 'Great Volleyball shoe!',
#   'unixReviewTime': 1169078400},
#  'B00009PO1X.A3KEKJK7OM9J12': {'asin': 'B00009PO1X',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'received product in a timely fashion, the shoes were new and great quality. It was the first purchase I made from this merchant, I have made three more since then.',
#   'reviewTime': '11 6, 2006',
#   'reviewerID': 'A3KEKJK7OM9J12',
#   'reviewerName': 'Michael E. Boyle',
#   'summary': 'Great Product',
#   'unixReviewTime': 1162771200},
#  'B00009V195.A34VC1QTSZVJJR': {'asin': 'B00009V195',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'all ok great product',
#   'reviewTime': '07 12, 2014',
#   'reviewerID': 'A34VC1QTSZVJJR',
#   'reviewerName': 'Eduardo',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1405123200},
#  'B0000A62I5.AMHGMSH0C9PK6': {'asin': 'B0000A62I5',
#   'helpful': [4, 5],
#   'overall': 4.0,
#   'reviewText': 'My father has worn the same pair of adidas country shoes since 1977, when my mother bought the very last pair she could find after they were discontinued. To see his old-faithful reviatlized and put back on the market for a younger generation excites me not only as much as it does him. And the new model proves as stable as the old, which have stood the test of almost 30 years. A solid investment that could prove to last a quarter of a lifetime.',
#   'reviewTime': '12 9, 2002',
#   'reviewerID': 'AMHGMSH0C9PK6',
#   'reviewerName': '"ashleycm"',
#   'summary': 'A nice revamping of an old classic',
#   'unixReviewTime': 1039392000},
#  'B0000A62I5.AXZ1E3JMF14J1': {'asin': 'B0000A62I5',
#   'helpful': [1, 1],
#   'overall': 5.0,
#   'reviewText': "I bought my first pair of Adidas Country running shoes in 1977 when I was on my high school cross country team.  I've tried a bunch of other shoes over the years, but nothing comes close to this shoe for comfort and durability.  In 27 years I've managed to wear out three pairs and have just bought my fourth -- and that's wearing them and running in them almost every day in all types of weather and conditions.",
#   'reviewTime': '04 22, 2004',
#   'reviewerID': 'AXZ1E3JMF14J1',
#   'reviewerName': 'David',
#   'summary': 'A true classic of function and durability',
#   'unixReviewTime': 1082592000},
#  'B0000A62I5.A2CSJM0KM2OQ0S': {'asin': 'B0000A62I5',
#   'helpful': [4, 4],
#   'overall': 5.0,
#   'reviewText': "I used to wear these when I was a deep sea diver in the navyback in 77-81. We ran 10k (6.2 mi) everyday. I went through 2 pair back in the day. These shoes feel like a custom leather glove once they're broken in and look very cool w straight leg jeans. They carried me all over the back alleys of Europe. ;-) Can't believe they are making them available. Word to the wise. Mine just arrived. Go up a half size.",
#   'reviewTime': '07 19, 2006',
#   'reviewerID': 'A2CSJM0KM2OQ0S',
#   'reviewerName': 'Jeem',
#   'summary': 'Adidas Country II',
#   'unixReviewTime': 1153267200},
#  'B0000A62I5.A88OKJEGMS9B2': {'asin': 'B0000A62I5',
#   'helpful': [1, 1],
#   'overall': 4.0,
#   'reviewText': 'One of the best sneakers ever!!Comfortable, ruged and good looks.Can you guys post it on sizes 12 and 13?',
#   'reviewTime': '01 3, 2008',
#   'reviewerID': 'A88OKJEGMS9B2',
#   'reviewerName': 'Omar Bethencourt',
#   'summary': 'Cool shoes!!',
#   'unixReviewTime': 1199318400},
#  'B0000A889O.A3Q5BP3ACSO95M': {'asin': 'B0000A889O',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': "The only reason I don't give the 5 stars to this shoe is because the rubber tip sort of hurts your big toe. No matter how I laced them, tight or loosen, it was hurtful, up to point I had to stop using them.",
#   'reviewTime': '04 10, 2011',
#   'reviewerID': 'A3Q5BP3ACSO95M',
#   'reviewerName': 'Alejandro Castillo',
#   'summary': 'Acceptable Basketball Shoe.',
#   'unixReviewTime': 1302393600},
#  'B0000A8QKI.A2ILJCOTBJX009': {'asin': 'B0000A8QKI',
#   'helpful': [3, 4],
#   'overall': 3.0,
#   'reviewText': 'These are listed in the "running" section, so I thought an interior key pocket would be a given.  What a hassle to have to return these, especially given the seller\'s return policy, which I would encourage you to thoroughly check out before purchasing (by the time I return these I expect to have almost paid the price of the shorts - just for shipping - and they don\'t even weigh a whole pound).  Hopefully this review helps someone else to whom a key pocket is important.  I give them 2 stars for being cute, though.',
#   'reviewTime': '09 23, 2005',
#   'reviewerID': 'A2ILJCOTBJX009',
#   'reviewerName': 'Kathryn L. Smith',
#   'summary': 'No interior key pocket!',
#   'unixReviewTime': 1127433600},
#  'B0000AF46V.A1HZIYGUM1YR7Z': {'asin': 'B0000AF46V',
#   'helpful': [1, 1],
#   'overall': 3.0,
#   'reviewText': "I bought two pairs of Adidas cleats. This was one of the pairs.I purchased them thinking of the comfort they seemed to provide based on the  photo. And yes, they're very comfortable, it's like wearing a regular sneaker, but alas, after 20 minutes of sprinting on the field my legs really began to burn, the weight these cleats have is at least twice that of a regular mid cleat.I'd rather wear some worn down pairs I have at home that these, the unnecessary added strain on my legs is just too much.",
#   'reviewTime': '07 1, 2008',
#   'reviewerID': 'A1HZIYGUM1YR7Z',
#   'reviewerName': 'Oscar Blanco',
#   'summary': 'Confortable but extremely heavy!',
#   'unixReviewTime': 1214870400},
#  'B0000AS8DL.A8B6MTL22XFDQ': {'asin': 'B0000AS8DL',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': 'Good price but the shoes were really old,Am a little concerned with how long they will hold up .. shoes only have so much shelf life the they start to get brittle',
#   'reviewTime': '06 8, 2014',
#   'reviewerID': 'A8B6MTL22XFDQ',
#   'reviewerName': 'rzuace',
#   'summary': 'oldie but so far so good',
#   'unixReviewTime': 1402185600},
#  'B0000ASIXE.A1D81FDEWWNGR0': {'asin': 'B0000ASIXE',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'I have a questionI have a questionI have a questionI have a questionI have a question....Are This shoes for men?Thanks a lot for your help',
#   'reviewTime': '11 22, 2011',
#   'reviewerID': 'A1D81FDEWWNGR0',
#   'reviewerName': 'Jesus',
#   'summary': 'Information',
#   'unixReviewTime': 1321920000},
#  'B0000DDQD7.A1ZA22MS89KDP0': {'asin': 'B0000DDQD7',
#   'helpful': [0, 1],
#   'overall': 5.0,
#   'reviewText': 'I am delighted with this product. previously bought addias trainers,but found these are lite, hard wearing and very comfortable . After numeruous training sessions with senior and junior teams this lad on a underage team that my son plays with commented " Your Dad has the coolest BBall boots out their " . which made me feel 7 ft tall for a small man. EXCELLLANT PRODUCT.',
#   'reviewTime': '08 29, 2006',
#   'reviewerID': 'A1ZA22MS89KDP0',
#   'reviewerName': 'DemonCo "Den"',
#   'summary': 'corkycoach',
#   'unixReviewTime': 1156809600},
#  'B0000DDQD7.A2KGEAJIYZVX8V': {'asin': 'B0000DDQD7',
#   'helpful': [3, 3],
#   'overall': 5.0,
#   'reviewText': 'The first time I saw this shoe (in black/white patent leather) was on the feet of Boston Celtics All-Star forward Antoine Walker. Being a fan of "old-school" shoes and Mr. Walker, I immediately took a liking to the Adidas Promodel 2G.The Adidas Promodel line has been around for over four decades now and many a current and former NBA player has spent time in a pair, whether in high school, college or at the pro level. The first thing that stood out to me was how Adidas kept the classic "shell toe" as part of the shoe while adding minor adjustments to give it a nice blend of modern/retro looks. The patent leather also gives it a nice touch making the shoe simple, but unique.Another huge plus which I\'m sure everyone will notice is the price. ... it ain\'t gonna clean out too many pockets and for this price y\'all can go out and cop a pair or two (one for home games, one for the road). So, the bottom line on the Adidas Promodel 2G is that it\'s worth considering if you\'re a junior high or high school-level team looking for a good value in a team shoe (... the Promodel costs a lot less than most shoes designed for team use) or if you need a shoe for those lazy Sunday afternoon games down at the park.',
#   'reviewTime': '11 15, 2002',
#   'reviewerID': 'A2KGEAJIYZVX8V',
#   'reviewerName': '"elchino23"',
#   'summary': 'a classic update for a classic shoe',
#   'unixReviewTime': 1037318400},
#  'B0000DDQD7.A1GS5X3OE81KRF': {'asin': 'B0000DDQD7',
#   'helpful': [1, 3],
#   'overall': 1.0,
#   'reviewText': 'I bought these shoes from Eastbay.  They are the worst pair of shoes that I have ever worn in my life.  After wearing them for less than a week, I have identical cuts on both of my ankles from where the shoe jabbed into my skin.  There is a flexible backing on the shoe which is sewn to the inside right where your ankle goes.  As you walk, it grinds into your ankle and makes walking extremely uncomfortable.  I HIGHLY recommend not buying this product.',
#   'reviewTime': '02 2, 2005',
#   'reviewerID': 'A1GS5X3OE81KRF',
#   'reviewerName': 'EZMac3434',
#   'summary': 'Awful',
#   'unixReviewTime': 1107302400},
#  'B0000DDQD7.A37D3IW45D6JMO': {'asin': 'B0000DDQD7',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "these are great shoes -- light-weight but snug well-fitting -- great old school look and feel! i'd buy these again!",
#   'reviewTime': '02 18, 2014',
#   'reviewerID': 'A37D3IW45D6JMO',
#   'reviewerName': 'KEITH G GOLSTON',
#   'summary': 'i love pro-model adidas',
#   'unixReviewTime': 1392681600},
#  'B0000DDQD7.A2JU07LM3OQUFZ': {'asin': 'B0000DDQD7',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "I have 2 pairs of this model shoe and love them.  After being a Nike fan for years I decided to give something else a try.  This shoe is lightweight and very comfortable.  I also love the classic style.  And you can't complain about the nice price.",
#   'reviewTime': '01 8, 2003',
#   'reviewerID': 'A2JU07LM3OQUFZ',
#   'reviewerName': '"mi_icatchr"',
#   'summary': 'great shoe, great price',
#   'unixReviewTime': 1041984000},
#  'B0000DDQD7.A2QDOJFFLFGF18': {'asin': 'B0000DDQD7',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'These shoes are comfortable as well as long lasting. They do not make your feet sweat or smell bad like other high top shoes. This shoe never goes op of style',
#   'reviewTime': '10 25, 2010',
#   'reviewerID': 'A2QDOJFFLFGF18',
#   'reviewerName': 'Mr and Mrs Michael Alexander "greenacres"',
#   'summary': 'Great shoe',
#   'unixReviewTime': 1287964800},
#  'B0000ERYHJ.A2DU5HQRUCVNMV': {'asin': 'B0000ERYHJ',
#   'helpful': [1, 1],
#   'overall': 5.0,
#   'reviewText': 'My son is on two baseball teams and needed a different type of cleat for each team. We searched in the stores and they were quite expensive, then I came across this deal on line. It was great. I was able to get my son both pairs of cleats he needed for the price that it would have cost me for one in the stores at our local mall.',
#   'reviewTime': '03 16, 2009',
#   'reviewerID': 'A2DU5HQRUCVNMV',
#   'reviewerName': 'Karlee Herget',
#   'summary': 'Excellent value for the price.',
#   'unixReviewTime': 1237161600},
#  'B0000ERYI9.A33O67FDFBT09E': {'asin': 'B0000ERYI9',
#   'helpful': [0, 0],
#   'overall': 3.0,
#   'reviewText': "My brother and I wear the same size of shoes, so he bought these and I wore them 2 days, they are too tight at the toe area, so my toes were a little sore the second time I used them. I purchased the Mizuno Men's 9-Spike Pro Limited Low G4 Cleat, and these are much more comfortable a more wide toe area.",
#   'reviewTime': '01 14, 2009',
#   'reviewerID': 'A33O67FDFBT09E',
#   'reviewerName': 'Juan Ponce Casasola',
#   'summary': 'Too tight at toe area',
#   'unixReviewTime': 1231891200},
#  'B00015LGSE.A310XHA0DAORFC': {'asin': 'B00015LGSE',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'Great pair of Golf Shoes, fits to size. Great price for Adidas mens golf shoes.  I would purchase agian.',
#   'reviewTime': '10 2, 2009',
#   'reviewerID': 'A310XHA0DAORFC',
#   'reviewerName': 'Aqua "Ann"',
#   'summary': 'Adidas Adiiwear 3 stripes',
#   'unixReviewTime': 1254441600},
#  'B0001FSB6Y.A1WUMQ5MOQ7VY5': {'asin': 'B0001FSB6Y',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'fue un regalo para mi hijo que le encanto mucho y son de buena c&aacute;lida son confortables excelente producto los recomiendo',
#   'reviewTime': '01 25, 2013',
#   'reviewerID': 'A1WUMQ5MOQ7VY5',
#   'reviewerName': 'ANDERSON CASTILLO',
#   'summary': 'anderson castillo',
#   'unixReviewTime': 1359072000},
#  'B0001M48GY.A3G39K8HO6TAOZ': {'asin': 'B0001M48GY',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'my wife wears small size, hard to find good fit. very pleased with her purchase',
#   'reviewTime': '05 7, 2007',
#   'reviewerID': 'A3G39K8HO6TAOZ',
#   'reviewerName': 'Howard  J. K.',
#   'summary': 'very comfortable',
#   'unixReviewTime': 1178496000},
#  'B0001SYM46.A37HCSGGRH8UO6': {'asin': 'B0001SYM46',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "This is a great, comfortable shoe custom-made by one of the greatest NBA ballers in history, T-Mac! Some of you might know him as Tracy McGrady, guard for the Orlando Magic/Houston Rockets. If you love basketball, and you want to build your skills up, you gotta be buyin' this shoe. It is WHACK! Now, my man Melo's gotta release a shoe, like his bro Lebron did.",
#   'reviewTime': '07 1, 2004',
#   'reviewerID': 'A37HCSGGRH8UO6',
#   'reviewerName': 'C. Conard "ExtremeAvalanche"',
#   'summary': 'Great...',
#   'unixReviewTime': 1088640000},
#  'B000214PQM.A3TC9PXICZ4ET5': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 3.0,
#   'reviewText': "These are good compression shorts, but I find the waistband to be too large for my liking. I ordered a couple pairs, and I'll gladly use them until they are worn out, but I won't be buying any more pairs of these shorts due to the excessively large waist band.",
#   'reviewTime': '02 17, 2014',
#   'reviewerID': 'A3TC9PXICZ4ET5',
#   'reviewerName': 'Almeson',
#   'summary': 'Good compression shorts',
#   'unixReviewTime': 1392595200},
#  'B000214PQM.A2Z10INIM6SIYA': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 3.0,
#   'reviewText': 'these shorts are ok.  I like to wear compression shorts as underwear when i exercise but these shorts are a little bulks.  I like the fit of nike pro combat compression shorts better',
#   'reviewTime': '11 24, 2013',
#   'reviewerID': 'A2Z10INIM6SIYA',
#   'reviewerName': 'Amazon Customer',
#   'summary': 'not good underwear',
#   'unixReviewTime': 1385251200},
#  'B000214PQM.A3IWAAAQNJC05Y': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "A lot more comfortable than I expected. Needed them for the crew team wasn't sure they were the right thing but they were.",
#   'reviewTime': '09 17, 2013',
#   'reviewerID': 'A3IWAAAQNJC05Y',
#   'reviewerName': 'Anibal Perez',
#   'summary': 'Good Shorts',
#   'unixReviewTime': 1379376000},
#  'B000214PQM.A1AUWQQVM1URG9': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': "i also have the black samba design so i thought why not vary and order the white version. as with the back version, it is extremely comfortable and for me at least prevents chafe after a long run of more than 15km. i ordered the medium size so the will seat extra tight (i'm 180cm, 80 kg). i also find them perfect for swimming. the only downside is that they tend to get a bit transparent when wet and while combined with a dark underpants.",
#   'reviewTime': '09 19, 2012',
#   'reviewerID': 'A1AUWQQVM1URG9',
#   'reviewerName': 'Asaf',
#   'summary': 'great fit, can be a bit transparent',
#   'unixReviewTime': 1348012800},
#  'B000214PQM.A863J10079C9Y': {'asin': 'B000214PQM',
#   'helpful': [1, 1],
#   'overall': 5.0,
#   'reviewText': 'Great tights for running! I run and off-road bike, so these are perfect for me. They are MINIMALIST, meaning that they are no frills, non-padded, non-compression, non-thermal running shorts. They fit like a glove, stay where they need to be and have a single inside pocket for your key or credit card. They are really great if you wear a hydration pack, since there is no bunching like other shorts. However, I do recommend wearing briefs underneath, just in case...you know. Otherwise, these are not for you. Hope this helps!',
#   'reviewTime': '03 20, 2012',
#   'reviewerID': 'A863J10079C9Y',
#   'reviewerName': 'Chef Rob',
#   'summary': 'Minimalist Running Tights',
#   'unixReviewTime': 1332201600},
#  'B000214PQM.A1XCX9JK6S7GW1': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'I use these for running indoors on my treadmill. For the price, they are worth every cent. I highly recommend this product.',
#   'reviewTime': '12 6, 2012',
#   'reviewerID': 'A1XCX9JK6S7GW1',
#   'reviewerName': 'Christopher "Chris"',
#   'summary': 'These shorts are perfect for running',
#   'unixReviewTime': 1354752000},
#  'B000214PQM.A15TUJW4N49R6V': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': 'They are a tiny bit looser than expected but my husband says they are very comfortable and they work soon he will have to go down in size',
#   'reviewTime': '08 15, 2013',
#   'reviewerID': 'A15TUJW4N49R6V',
#   'reviewerName': 'Courtney A Bartorelli',
#   'summary': 'Great',
#   'unixReviewTime': 1376524800},
#  'B000214PQM.A388AC1Y4N9AGH': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': 'Good product for a great price..  may not be as good as under armour.. I ordered a size bigger and it fit perfectly..',
#   'reviewTime': '07 7, 2012',
#   'reviewerID': 'A388AC1Y4N9AGH',
#   'reviewerName': 'DD',
#   'summary': 'good buy',
#   'unixReviewTime': 1341619200},
#  'B000214PQM.A3NVWHNXBR0T9P': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'My son was very happy with these shorts.  He runs in them and is very comfortable in them, too.  I would recommend.',
#   'reviewTime': '01 11, 2012',
#   'reviewerID': 'A3NVWHNXBR0T9P',
#   'reviewerName': 'dram',
#   'summary': "Adidas Men's Short Tights",
#   'unixReviewTime': 1326240000},
#  'B000214PQM.A30BFAW49DDE6W': {'asin': 'B000214PQM',
#   'helpful': [1, 1],
#   'overall': 5.0,
#   'reviewText': 'nice and tight, perfect.  Nice and smooth and easy to wash, these are great for sports.  Perfect with tight underwear i would reccomend white briefs because it would not show through',
#   'reviewTime': '01 6, 2012',
#   'reviewerID': 'A30BFAW49DDE6W',
#   'reviewerName': 'gb',
#   'summary': 'great',
#   'unixReviewTime': 1325808000},
#  'B000214PQM.A2X4NH0ZOMJA4F': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'This pants is awesome. I use it to workout also to swim or in a hot tub. It gives me the right support without restricting. Love it!',
#   'reviewTime': '12 3, 2013',
#   'reviewerID': 'A2X4NH0ZOMJA4F',
#   'reviewerName': 'G. Wetzel',
#   'summary': 'right support, not too tight',
#   'unixReviewTime': 1386028800},
#  'B000214PQM.A2R2V242821Y7Y': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'These exercise tights fit well and are well made with good quality material. I ordered two and only one was shipped which is a bit annoying.',
#   'reviewTime': '11 10, 2011',
#   'reviewerID': 'A2R2V242821Y7Y',
#   'reviewerName': 'HeartFixr "HeartFixr"',
#   'summary': 'Adidas short review',
#   'unixReviewTime': 1320883200},
#  'B000214PQM.A4BMPIJMMLWAJ': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'I love these compression shorts. I have bought a few of these and use them everday to excersise. They are good quality and I would recommend',
#   'reviewTime': '02 13, 2013',
#   'reviewerID': 'A4BMPIJMMLWAJ',
#   'reviewerName': 'J. Hilsen',
#   'summary': "adidas Men's Samba Short Tight (White, Black, X-Large)",
#   'unixReviewTime': 1360713600},
#  'B000214PQM.AJDJD2Q39Q8DE': {'asin': 'B000214PQM',
#   'helpful': [3, 3],
#   'overall': 5.0,
#   'reviewText': "I really enjoyed these shorts I wear to the gym all the time. They are very comfortable and feel great. I just wear plain without shorts over, you'll be fine. Happy shopping.",
#   'reviewTime': '09 26, 2011',
#   'reviewerID': 'AJDJD2Q39Q8DE',
#   'reviewerName': 'Jose',
#   'summary': 'Love These Shorts. Great for the Gym',
#   'unixReviewTime': 1316995200},
#  'B000214PQM.A14A7THRKRI0OL': {'asin': 'B000214PQM',
#   'helpful': [0, 1],
#   'overall': 5.0,
#   'reviewText': "it's sweet and really good. I like it it's sweet and really good. I like it it's sweet and really good. I like it",
#   'reviewTime': '02 5, 2013',
#   'reviewerID': 'A14A7THRKRI0OL',
#   'reviewerName': 'Josh junyiguo',
#   'summary': "it's sweet and really good. I like it it's sweet and really good. I like it",
#   'unixReviewTime': 1360022400},
#  'B000214PQM.A2VRYQBXSTA424': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 2.0,
#   'reviewText': "I wear lots of compression shorts from a wide range of brands. I wear them for lifting, running, basketball, and even general day-to-day use. That said, these are the first that I've run into that I actually dislike. Simply put, they're cut weird. They're a tad too tight (mainly around the waist), and they seem too long. (i.e. They ride above my waste.) They just don't work for me.So far, I've come to find that Nike and Champion offer the best for my build and body type. Nike's are great, but I can't say they're worth the extra price of Champions that you can find on Amazon. Regardless of my choice between those, there's no doubt that I won't be buying any more of this style. (I plan to check out other Adidas options to see whether it's a brand thing or just a specific thing to this particular product.)",
#   'reviewTime': '01 20, 2014',
#   'reviewerID': 'A2VRYQBXSTA424',
#   'reviewerName': 'Joshua T. Ebert "Ebes"',
#   'summary': 'Weird Fit',
#   'unixReviewTime': 1390176000},
#  'B000214PQM.A2K7N2E8V89EVN': {'asin': 'B000214PQM',
#   'helpful': [6, 8],
#   'overall': 4.0,
#   'reviewText': 'Thanks to the Amazon images, I ordered these Adidas Men\'s Samba Shorts in anticipation of a 48-mile mass bike ride.  They arrived perfectly and securely packaged.  I\'m a 36 waist, so I ordered Large; these shorts barely pulled on, so when you order, go up a couple of sizes.  The need to order up in size and the fact that I couldn\'t use the ones I ordered explains my 4 rating; I\'m hoping to Edit that to a 5 when I order the extra-large shorts.  The white ones I ordered were startlingly bright, as I hoped, so despite the size issue-which is easily handled-I recommend these for your biking this season. All the better, they come in three colors.adidas Men\'s Samba Short TightI next ordered extra large, and they were still a bit snug at the waist, though they\'re fine below the waist line.  I\'d suggest going several sizes larger than usual, but they\'re worth it.  If you\'re modest, you\'ll want to wear something under them.  Visibility is a factor.  I\'m adding one note:  I measured, and I\'m a 36 inch, not 34.  It\'s good to see others\' experiences were better, since for this price, it\'s worth getting your own experience. I just figured XL would be loose on a 36" waist.',
#   'reviewTime': '09 18, 2011',
#   'reviewerID': 'A2K7N2E8V89EVN',
#   'reviewerName': 'J Resb',
#   'summary': 'Nice looking but order larger',
#   'unixReviewTime': 1316304000},
#  'B000214PQM.A4QVENBCG2U1F': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 3.0,
#   'reviewText': "Fit and finish are very good, as you would expect from adidas. These are pretty comfortable; in fact, my only (mild) complaint is that I'd like them to offer a little more compression.",
#   'reviewTime': '10 9, 2012',
#   'reviewerID': 'A4QVENBCG2U1F',
#   'reviewerName': 'Kevinva',
#   'summary': 'Good Quality',
#   'unixReviewTime': 1349740800},
#  'B000214PQM.A2G44JSXC64BYE': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'Excellent product - consistent with adidas reputation.  Iwill likely be purchasing additional Samba Fitness Shorts in the future of other colors.',
#   'reviewTime': '02 1, 2013',
#   'reviewerID': 'A2G44JSXC64BYE',
#   'reviewerName': 'K. Flanagan',
#   'summary': 'Samba Fitness Short',
#   'unixReviewTime': 1359676800},
#  'B000214PQM.A3NYL4I3EA6JY': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'The short fit perfectly and still do sweat after sweat and wash after wash.very reliable for physical sports or just to exercise in.',
#   'reviewTime': '12 9, 2012',
#   'reviewerID': 'A3NYL4I3EA6JY',
#   'reviewerName': 'Martin M',
#   'summary': 'Great',
#   'unixReviewTime': 1355011200},
#  'B000214PQM.A27DQK3QFVNJGJ': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'I bought these shorts primarily for playing soccer. They have been perfect; right size, quality, and keep you comfortable. I would definitely recommend it to others.',
#   'reviewTime': '10 12, 2011',
#   'reviewerID': 'A27DQK3QFVNJGJ',
#   'reviewerName': 'MP',
#   'summary': 'Wonderful Shorts',
#   'unixReviewTime': 1318377600},
#  'B000214PQM.A20K45DSYHI3RI': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': 'I really like these. You need to be careful when ordering the size. I ordered a large and I have a 34&#34; waist. They are pretty tight. I really like that the material is a little thicker that normal compression shorts. I would definitely order another pair. They were also shipped pretty fast.',
#   'reviewTime': '11 30, 2012',
#   'reviewerID': 'A20K45DSYHI3RI',
#   'reviewerName': 'nicklaus',
#   'summary': 'good product',
#   'unixReviewTime': 1354233600},
#  'B000214PQM.A3UEBFIN1PQ1L0': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'Just bought these compression shorts wore them for exercising and some sparring for my Karate they are good they give me support and flexibility.',
#   'reviewTime': '12 6, 2011',
#   'reviewerID': 'A3UEBFIN1PQ1L0',
#   'reviewerName': 'Oscar',
#   'summary': 'Good Quality',
#   'unixReviewTime': 1323129600},
#  'B000214PQM.A28YKXAX8DMGSE': {'asin': 'B000214PQM',
#   'helpful': [2, 2],
#   'overall': 1.0,
#   'reviewText': 'Although material feel confortable, the shrts offers minimal compression, feels no different than  regular long briefs. If you are looking for tighter compression, I recommend trying the Bike brand.',
#   'reviewTime': '06 3, 2012',
#   'reviewerID': 'A28YKXAX8DMGSE',
#   'reviewerName': 'RG',
#   'summary': 'No tight enough',
#   'unixReviewTime': 1338681600},
#  'B000214PQM.A2V246QM605YQ3': {'asin': 'B000214PQM',
#   'helpful': [10, 10],
#   'overall': 5.0,
#   'reviewText': 'A no nonsense great fitting compression short. Good price and great quality. Size and fit is right. Material quality is better than some that are priced higher.  Very satisfied.',
#   'reviewTime': '05 12, 2010',
#   'reviewerID': 'A2V246QM605YQ3',
#   'reviewerName': 'Robhart',
#   'summary': 'Compression shorts',
#   'unixReviewTime': 1273622400},
#  'B000214PQM.A22TAW1I205SAY': {'asin': 'B000214PQM',
#   'helpful': [5, 5],
#   'overall': 3.0,
#   'reviewText': "These are stretchy and they fit fine, but they are really thin. I bought these for rowing, but I think they would work better as underwear. I was expecting something about 4X thicker and tighter. Not a bad product, I just don't really understand why they are so thin.",
#   'reviewTime': '11 16, 2012',
#   'reviewerID': 'A22TAW1I205SAY',
#   'reviewerName': 'Sam',
#   'summary': 'These are pretty thin',
#   'unixReviewTime': 1353024000},
#  'B000214PQM.A3GSQE0LXPG9YF': {'asin': 'B000214PQM',
#   'helpful': [3, 5],
#   'overall': 5.0,
#   'reviewText': 'I bought these shorts to show off my package for Halloween and boy, it showed every thing! Nice and tight too! They felt very comfortable as well.',
#   'reviewTime': '12 1, 2011',
#   'reviewerID': 'A3GSQE0LXPG9YF',
#   'reviewerName': 'Sean Serritella',
#   'summary': 'Great Shorts - Nice and Tight',
#   'unixReviewTime': 1322697600},
#  'B000214PQM.A39RH1M6ORHX9Q': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 1.0,
#   'reviewText': 'Searched for &#34;compression shorts&#34; to find these and these are not a compression short. Sizing was not accurate on the chart and ordered a size too small. Returned them due as they were not functional or fitting.',
#   'reviewTime': '12 27, 2012',
#   'reviewerID': 'A39RH1M6ORHX9Q',
#   'reviewerName': 'spazz',
#   'summary': 'Sizing not accurate',
#   'unixReviewTime': 1356566400},
#  'B000214PQM.A3622X7LU1A7C6': {'asin': 'B000214PQM',
#   'helpful': [0, 0],
#   'overall': 3.0,
#   'reviewText': 'These run larger than normal.  Order down one size.  Bought my normal size and I should have gone down two sizes.',
#   'reviewTime': '07 30, 2013',
#   'reviewerID': 'A3622X7LU1A7C6',
#   'reviewerName': 'speedodfw@aol.com "Speedo Dallas"',
#   'summary': 'Run Larger than normall',
#   'unixReviewTime': 1375142400},
#  'B0002HB22G.A38DQX9GQS6FQY': {'asin': 'B0002HB22G',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'the best shoes for softball grip in the field without setbacks are perfect I recommend the shipping was fast and smooth',
#   'reviewTime': '01 9, 2011',
#   'reviewerID': 'A38DQX9GQS6FQY',
#   'reviewerName': 'Eduardo Nuez "rookie"',
#   'summary': 'the best',
#   'unixReviewTime': 1294531200},
#  'B0002K03I2.A1GL5V0FBCGH6D': {'asin': 'B0002K03I2',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'I could not believe how fast I got my shoes. I am a tennis professional and I strongly recommend the Adidas Barricade. They are very comfortable,last a long time and look great. I have been bying them for years. You will love them!!!!',
#   'reviewTime': '10 7, 2011',
#   'reviewerID': 'A1GL5V0FBCGH6D',
#   'reviewerName': 'lucia',
#   'summary': 'Awesome product.',
#   'unixReviewTime': 1317945600},
#  'B00069V8VK.A3I0T6FZ5M0AKU': {'asin': 'B00069V8VK',
#   'helpful': [0, 2],
#   'overall': 5.0,
#   'reviewText': 'hola todo fino  Excelenteeeeee muy hola todo fino gustaooo muchoooooo everything right all excellent recommendy poreque esta muy buernono em ha llegadotodo bien lo recomiendobuenoooooooooooooooooooo recomendado',
#   'reviewTime': '11 23, 2012',
#   'reviewerID': 'A3I0T6FZ5M0AKU',
#   'reviewerName': 'Carlos E.Cabrera Morin',
#   'summary': 'hello',
#   'unixReviewTime': 1353628800},
#  'B00069VDRO.A1FGV5B5OA1P1Q': {'asin': 'B00069VDRO',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'These are the best shoes I have ever worn in any sport. I play senior "over 50" slow pitch softball and the cushion in these are gentle on old knees. Several ladies on the team bought them and all rave about them.',
#   'reviewTime': '01 7, 2008',
#   'reviewerID': 'A1FGV5B5OA1P1Q',
#   'reviewerName': 'Softball Oldie',
#   'summary': 'Fantastic shoes',
#   'unixReviewTime': 1199664000},
#  'B0006BH074.A2I5U8GJM0GZV4': {'asin': 'B0006BH074',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "I bought for my husband.  It is so light and nice.  Just he can't wear when the weather is too wet.",
#   'reviewTime': '12 28, 2012',
#   'reviewerID': 'A2I5U8GJM0GZV4',
#   'reviewerName': 'momo',
#   'summary': 'light and nice',
#   'unixReviewTime': 1356652800},
#  'B0006H2GM2.A3LVRQBKXTMPZN': {'asin': 'B0006H2GM2',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'this t was perfect and has lasted me about 5 yearsit drops at the perfect length for me and was a gr8 investment.',
#   'reviewTime': '06 12, 2012',
#   'reviewerID': 'A3LVRQBKXTMPZN',
#   'reviewerName': 'pinnywallo',
#   'summary': 'long lasting',
#   'unixReviewTime': 1339459200},
#  'B0006MRBXQ.A31MBGFUXTCFWF': {'asin': 'B0006MRBXQ',
#   'helpful': [0, 2],
#   'overall': 5.0,
#   'reviewText': 'Go Fast Kicks w/ screw-in spike cleats for traction and golf and running and Israeli Krav Maga Martial-Arts / Self-Defense devastation of your attacker / rapist creep...All-Purpose track sneaks! Kudos Addidas!',
#   'reviewTime': '03 4, 2008',
#   'reviewerID': 'A31MBGFUXTCFWF',
#   'reviewerName': 'Marilena-Siobhan Kenny "# 1 Luaka Bopper"',
#   'summary': 'Go Fast Kicks',
#   'unixReviewTime': 1204588800},
#  'B0006V4DPG.A11VG3IJIMJXGV': {'asin': 'B0006V4DPG',
#   'helpful': [1, 1],
#   'overall': 4.0,
#   'reviewText': "High in style, and high in comfort, this sneaker is great to wear with jeans, track suits, and even miniskirts.  So comfy.  Only thing is, I wish it has a little more cushioning, but it's not a heavy duty walking shoe like a merrell or ecco.",
#   'reviewTime': '01 1, 2005',
#   'reviewerID': 'A11VG3IJIMJXGV',
#   'reviewerName': 'Kristy Howard "Student"',
#   'summary': 'Comfortable and Sporty',
#   'unixReviewTime': 1104537600},
#  'B000787LDY.A3JR3NYF4RD23T': {'asin': 'B000787LDY',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "I actually purchased these in a retail store, but was so impressed I just wanted to leave a review here. Tried on this shoe at the recommendation of a clerk. I told him I didn't like lightweight shoes because they don't have enough cushioning. He was about 6'3&#34;, 210 lbs, so I figured there had to be something to them if he liked them. Lo and behold, he was right !  I ran the 2014 AJC Peachtree Roadrace in them, and they are wonderful. Perfect combo&#8230;.lightweight, great cushioning in sole, breathability, decent price. Btw, I'm 46, 5'11&#34;, 178lbs&#8230;..now, run along !!",
#   'reviewTime': '07 8, 2014',
#   'reviewerID': 'A3JR3NYF4RD23T',
#   'reviewerName': 'Rodney',
#   'summary': 'Lightweight with cushioning',
#   'unixReviewTime': 1404777600},
#  'B0007CZNYE.A2MG83QIC8HVGK': {'asin': 'B0007CZNYE',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': "This shoe is comfortable to wear and play soccer for over an hour.Some can find the space at the tip too much but I don't mind it.",
#   'reviewTime': '01 9, 2007',
#   'reviewerID': 'A2MG83QIC8HVGK',
#   'reviewerName': 'Seckin Gokaltun',
#   'summary': 'Nice soccer shoe.',
#   'unixReviewTime': 1168300800},
#  'B0007LYN5A.A1TVWJSZFLOS3L': {'asin': 'B0007LYN5A',
#   'helpful': [0, 1],
#   'overall': 3.0,
#   'reviewText': "these shoes could have been great, but fell short in the most important department: comfort.  materials and craftmanship are great.  design is great and i commend the designer(s) for the thought and ingenuity they put into the shoe.  the only thing they missed is to make sure there were no hot spots, which there are.  if you ever bend your foot more than 90 degrees, you may feel the tendons on top of your foot (all around your ankle) rubbing against the top opening of the shoe very uncomfortably.  do that for any period of time, and your wonderful day at the trail has just become torture.  this situation is accentuated if you spend any amount of time off the bike hiking uphill, for that makes the ankle have a more acute angle.  of course, fit is subjective, but i've never had this problem with any other type of shoe (cycling or otherwise).  finally, these may not be the best shoes for very rocky terrain, as they offer minimal toe protection.",
#   'reviewTime': '04 4, 2006',
#   'reviewerID': 'A1TVWJSZFLOS3L',
#   'reviewerName': 'J. R. Correa',
#   'summary': "could've been great...",
#   'unixReviewTime': 1144108800},
#  'B0007PN6E0.A33K9ZSC6W7N1X': {'asin': 'B0007PN6E0',
#   'helpful': [0, 0],
#   'overall': 3.0,
#   'reviewText': "These sandals do what I wanted -- keep water off my feet at the pool and provide a quick slip on/off at my other exercise classes.  But I was surprised how goofy these looked on me in person!  First, several reviewers recommended sizing up, but I would disagree.  I usually wear a 9.5 or 10, so I got a 10, and these extend over an inch behind my heels.  The band over the foot is excessively tall, making it pretty loose to walk in.  If you tighten the velcro, the top part of the band then sticks straight out to the side, which just looks silly.  Finally, I'm not sure if it's just the too-large size, but the sandals look much bulkier on me than they do in the picture.  They are fairly heavy and thick in both the sole and the band.  I'm very lazy about returning purchases so I kept these -- but I'd recommend skipping them and looking elsewhere.",
#   'reviewTime': '01 14, 2013',
#   'reviewerID': 'A33K9ZSC6W7N1X',
#   'reviewerName': 'Abby',
#   'summary': 'Functional but ugly!',
#   'unixReviewTime': 1358121600},
#  'B0007PN6E0.A1V82I9NY2FDJY': {'asin': 'B0007PN6E0',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'comfortable shoe, love thesewill buy more whenever these wear out. I love in florida and wear thesearound house, to beach, everywhere',
#   'reviewTime': '10 30, 2013',
#   'reviewerID': 'A1V82I9NY2FDJY',
#   'reviewerName': 'a "FilmmakerGirlz"',
#   'summary': 'great',
#   'unixReviewTime': 1383091200},
#  'B0007PN6E0.AH2NM0XRJ40TC': {'asin': 'B0007PN6E0',
#   'helpful': [0, 2],
#   'overall': 4.0,
#   'reviewText': "This is a great sandal except it runs 1 size too big. I am a size 8, and ordered a size 8, but it's about an inch too long. I would have needed a size 7 I guess.",
#   'reviewTime': '07 27, 2007',
#   'reviewerID': 'AH2NM0XRJ40TC',
#   'reviewerName': 'A. Guilbault',
#   'summary': 'Adidas "Adissage W" Slide',
#   'unixReviewTime': 1185494400},
#  'B0007PN6E0.A2ISR81JJKHKFB': {'asin': 'B0007PN6E0',
#   'helpful': [0, 2],
#   'overall': 3.0,
#   'reviewText': "Well i bought this product in black and white when they came they are too THICK at the soles. Makes me feel like im wearing those workout shoes. Ive worn them before so i can't return them. Wearing them without socks hurts like  ***** but they are durable and the black and white color LOOKS GOOD ON GUYS NOT LADIES !!! so LADIES  get PINK AND WHITE",
#   'reviewTime': '08 9, 2012',
#   'reviewerID': 'A2ISR81JJKHKFB',
#   'reviewerName': 'AlexandraLovesJose',
#   'summary': "It's ok for guys.",
#   'unixReviewTime': 1344470400},
#  'B0007PN6E0.AP9USU1C1C21P': {'asin': 'B0007PN6E0',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'I like the shoe after you start getting it to form to you its great',
# ...
#   'reviewTime': '12 11, 2012',
#   'reviewerID': 'A1W6J8KVFOJ3XQ',
#   'reviewerName': 'Karla Vasquez',
#   'summary': 'I like it so much',
#   'unixReviewTime': 1355184000},
#  'B0007PNAE6.A2OF3NUCMCVOBW': {'asin': 'B0007PNAE6',
#   'helpful': [3, 3],
#   'overall': 2.0,
#   'reviewText': 'Great looking and great feeling sandal.  It takes awhile to get used to the massagers.  Sadly, the massagers break off within a few weeks.  This happened with a similar style sandal from Adidas too.  I was hoping that the more expensive Santiossage would not do that.  For $30, the sandals should last longer than 2 or 3 weeks.',
#   'reviewTime': '08 22, 2010',
#   'reviewerID': 'A2OF3NUCMCVOBW',
#   'reviewerName': 'Kenneth L. Hoyt Jr.',
#   'summary': 'meh',
#   'unixReviewTime': 1282435200},
#  'B0007PNAE6.A25K626DXZ8WN9': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'I would recommend these shoes.. I bought a pair for each of the men in my family. They look so cute and the massage feels good!',
#   'reviewTime': '09 15, 2013',
#   'reviewerID': 'A25K626DXZ8WN9',
#   'reviewerName': 'Kimberly A Dunn-Clemons',
#   'summary': 'On time- great quality',
#   'unixReviewTime': 1379203200},
#  'B0007PNAE6.A3JWGAJ0CPZQYI': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'When I first got the sandals it was a pain to have on. They have these brissels on the sole of the foot so it was uncomfortable for a couple of days but I guess they softened up and now I wear them like everyday with socks and with out. The are very comfortable and not much else, because they are just sandels. Very good quality too, very durable... A MUST BUY... (If you need sandals)',
#   'reviewTime': '07 25, 2006',
#   'reviewerID': 'A3JWGAJ0CPZQYI',
#   'reviewerName': 'K. Rosario',
#   'summary': 'great sandals...',
#   'unixReviewTime': 1153785600},
#  'B0007PNAE6.A1DINSVW8ZHKDD': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'very comfortable and sturdy slipper, came with the correct size and left and right were correct too and the price is awesome',
#   'reviewTime': '10 7, 2012',
#   'reviewerID': 'A1DINSVW8ZHKDD',
#   'reviewerName': 'leigh',
#   'summary': 'satisfied',
#   'unixReviewTime': 1349568000},
#  'B0007PNAE6.A1O4WS0XJPWIAO': {'asin': 'B0007PNAE6',
#   'helpful': [2, 3],
#   'overall': 1.0,
#   'reviewText': "After about a month, the nubs start to come off of the sandal. You're then left with your big toe in a hole as the sides of your feet fall into a rut.",
#   'reviewTime': '03 31, 2008',
#   'reviewerID': 'A1O4WS0XJPWIAO',
#   'reviewerName': 'L. Garrison "Mike"',
#   'summary': 'Nubs come off',
#   'unixReviewTime': 1206921600},
#  'B0007PNAE6.A3REW0WSZWSOZC': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "When I was in high school I had a pair of these that I wore before and after soccer games. Since then I haven't had a pair. Recently, when I had my first child, I discovered that my feet and my lower back were really achy after days of walking around our apartment in socks or barefeet. I bought a pair of these to give me some arch support and stimulate circulation. They did the trick! Seriously, I no longer have that achy back! They are comfortable and cheap and last a long time. If your slippers are warm, but don't offer any arch support, try a pair of these!",
#   'reviewTime': '03 1, 2011',
#   'reviewerID': 'A3REW0WSZWSOZC',
#   'reviewerName': 'Lila',
#   'summary': 'A classic sandal',
#   'unixReviewTime': 1298937600},
#  'B0007PNAE6.A22EQF9ODPBCOQ': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'muchisimas gracias, me parecieron lo mejor.. rapido y atentos con mi compra, espero comprarles nuevamente en alguna oportunidad e mi vida. son buenaqs',
#   'reviewTime': '10 16, 2012',
#   'reviewerID': 'A22EQF9ODPBCOQ',
#   'reviewerName': 'Luis Quintero',
#   'summary': 'sandaleo',
#   'unixReviewTime': 1350345600},
#  'B0007PNAE6.A2KUEGMSLHUNNP': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "These are very comfortable, And this is actually the second set I'm buying. I've had the first pair for close to two years and still going strong. (Needed another color) I definitely recommend these.",
#   'reviewTime': '11 27, 2012',
#   'reviewerID': 'A2KUEGMSLHUNNP',
#   'reviewerName': 'Mark G',
#   'summary': 'Good Buy',
#   'unixReviewTime': 1353974400},
#  'B0007PNAE6.AR9IVRC5TMZJI': {'asin': 'B0007PNAE6',
#   'helpful': [2, 4],
#   'overall': 1.0,
#   'reviewText': 'hola escribo para publicar que el dise&ntilde;o de esta sandalia es de muy mala calidad en menos 2 1 mes se rompio. Es una perdida de dinero comprar este producto. saludos.Hello I write to publish the design of this sandal is very poor quality broke about a month. It is a waste of money buying this product. bye',
#   'reviewTime': '05 21, 2011',
#   'reviewerID': 'AR9IVRC5TMZJI',
#   'reviewerName': 'M. De Los Remedios "Martin_delosremedios"',
#   'summary': 'de mala calidad el dise&ntilde;o del calzado',
#   'unixReviewTime': 1305936000},
#  'B0007PNAE6.A378GG6GJ3UM8C': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 3.0,
#   'reviewText': 'The "Massage Knobs" hurt the bottom of my feet at first but they\'ve worn down now so they feel better. Don\'t wear shoes much, just these.',
#   'reviewTime': '03 19, 2007',
#   'reviewerID': 'A378GG6GJ3UM8C',
#   'reviewerName': 'Michael L. Buyanovich',
#   'summary': 'Uncomfortable at first',
#   'unixReviewTime': 1174262400},
#  'B0007PNAE6.A27AHLNFL63ZX5': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'I had a choice. Timberland slide or adidas ones. I owned both of them. And both are great slides. But I wear adidas becouse it does a massage when walking. Timberland I gave to my friend as a gift. His is happy with those. I am happy with mines. That is all.',
#   'reviewTime': '05 13, 2010',
#   'reviewerID': 'A27AHLNFL63ZX5',
#   'reviewerName': 'Mikhail',
#   'summary': 'Good slide :)',
#   'unixReviewTime': 1273708800},
#  'B0007PNAE6.A1S55GN25S1PDE': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'I love the feel and the quality. They are just what I expected, actually they are better then I excepted.',
#   'reviewTime': '05 15, 2007',
#   'reviewerID': 'A1S55GN25S1PDE',
#   'reviewerName': 'Monica D. Falciani "moniker"',
#   'summary': 'Excellent',
#   'unixReviewTime': 1179187200},
#  'B0007PNAE6.A25ZNS3UGB69M0': {'asin': 'B0007PNAE6',
#   'helpful': [2, 4],
#   'overall': 2.0,
#   'reviewText': "I have had these massage sandals by a few different manufacturers ... the little nubs on these which are what massage your soles... started breaking within a few days of wearing them.. I have had some that lasted a year before breaking down... Don't buy these!",
#   'reviewTime': '07 12, 2007',
#   'reviewerID': 'A25ZNS3UGB69M0',
#   'reviewerName': 'MrLatin "Just the facts!"',
#   'summary': 'Cheap imitation!',
#   'unixReviewTime': 1184198400},
#  'B0007PNAE6.A2K4UVHK9UJBGE': {'asin': 'B0007PNAE6',
#   'helpful': [4, 4],
#   'overall': 5.0,
#   'reviewText': 'These are great sandals.They may hurt your feet a little if you are not used to them but I think they are still one of the best you can buy!',
#   'reviewTime': '01 3, 2007',
#   'reviewerID': 'A2K4UVHK9UJBGE',
#   'reviewerName': 'Mthexuma "Mthexuma"',
#   'summary': 'Great Sandals',
#   'unixReviewTime': 1167782400},
#  'B0007PNAE6.A2S2J10U6EHRIS': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 3.0,
#   'reviewText': "I bought these back in 2010 and they produced them in Indonesia. Now they produce them in Vietnam, the design is slightly different, but the big change is the material. It's harder, less flexible, and I imagine more durable. So it will take longer to break in and I'm not sure if it will ever be as comfortable as the older ones. But on the plus side it should last longer. The curve is less though and it's not as comfortable to walk in as my old ones. That might change in time, but it's also a bit higher, so I guess it will never be like the old ones exactly. Things change!",
#   'reviewTime': '06 10, 2014',
#   'reviewerID': 'A2S2J10U6EHRIS',
#   'reviewerName': 'Nathan Filyk',
#   'summary': 'Different material than from 2010',
#   'unixReviewTime': 1402358400},
#  'B0007PNAE6.A3AG3ZHG78N4M5': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 1.0,
#   'reviewText': 'My husband hated them.  They have little extensions on the sole.  I thought he would be O.K. with that but he was not.  I had to return the slides.',
#   'reviewTime': '10 23, 2012',
#   'reviewerID': 'A3AG3ZHG78N4M5',
#   'reviewerName': 'Pat',
#   'summary': "Men's Santiossage Slide",
#   'unixReviewTime': 1350950400},
#  'B0007PNAE6.AKOZCF2N1NFOO': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'This purchase replaced an "ancient" pair that finally "disintegrated".  I\'m a runner and these sandals are great foot stimulation after a run.  Really appreciate finding them on line and excellent service in processing my purchase.',
#   'reviewTime': '08 20, 2009',
#   'reviewerID': 'AKOZCF2N1NFOO',
#   'reviewerName': 'Patrick Morgan',
#   'summary': 'Massage Sandals',
#   'unixReviewTime': 1250726400},
#  'B0007PNAE6.A2FMKJ314GSFKF': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': "I bought these slides for house slippers based on the other reviews I read.  I will give one caution, you may not like them in the first few weeks.  The first few times I wore them, my feet were really sore after about an hour or two.  I recommend wearing them with socks for a week or so until all the nobbies soften and become more flexible.  After this break-period, you'll be able to wear them any way you like and you'll love how they feel after a long day of wearing shoes.",
#   'reviewTime': '11 3, 2006',
#   'reviewerID': 'A2FMKJ314GSFKF',
#   'reviewerName': 'phun-key "phun-key"',
#   'summary': 'Give them time to break in and they are wonderful.',
#   'unixReviewTime': 1162512000},
#  'B0007PNAE6.A3IVF678US903B': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'My son requested soccer slides for Christmas and I ordered these.  He has worn them non stop since Christmas and loves them.',
#   'reviewTime': '01 9, 2012',
#   'reviewerID': 'A3IVF678US903B',
#   'reviewerName': 'PLM',
#   'summary': 'Just what he wanted',
#   'unixReviewTime': 1326067200},
#  'B0007PNAE6.A7FIGOSAFRP4Q': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'I wound up buying a different color than I normally buy because it was half off and I actually like the navy/clear/white more than the black. It matches more of my athletic soccer gear and most importantly, feels the same.',
#   'reviewTime': '05 9, 2014',
#   'reviewerID': 'A7FIGOSAFRP4Q',
#   'reviewerName': 'P. LoPresti',
#   'summary': 'I love these and love it even more when I can get it online at a better deal than at the stores',
#   'unixReviewTime': 1399593600},
#  'B0007PNAE6.A1DNZEVZ3Z4TXV': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'I\'m probably on my 20th pair of these sandals over a 12 year period due to constant, year-round use.  That\'s not to say that they "wear out" quickly, just that I "live in them" and accelerate the process of the nubs falling out. They are by far the most simple, comfortable sandals made - and I\'ve tried tons of other brands.  Happy loyal Santiossage buyer!',
#   'reviewTime': '02 24, 2010',
#   'reviewerID': 'A1DNZEVZ3Z4TXV',
#   'reviewerName': 'P. Persic',
#   'summary': "Best sandals I've ever owned.",
#   'unixReviewTime': 1266969600},
#  'B0007PNAE6.A2GGAQCOIDZOS4': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': "They are comfortable and exactly what I paid for. I wear them all the time. Even in cold weather because I'm just that crazy and they are just the great",
#   'reviewTime': '12 6, 2012',
#   'reviewerID': 'A2GGAQCOIDZOS4',
#   'reviewerName': 'QOAnderson',
#   'summary': 'Love em',
#   'unixReviewTime': 1354752000},
#  'B0007PNAE6.A1BAAYS8VLMHEV': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'i got these sandals yesterday, as fellows said, its not that comfy at the beginning, but, after wearing it for a while, you wouldn`t want to take it off... 5 stars, material, size and comfortability.',
#   'reviewTime': '06 10, 2011',
#   'reviewerID': 'A1BAAYS8VLMHEV',
#   'reviewerName': 'Rami Hasan',
#   'summary': 'Very Comfy,size fits',
#   'unixReviewTime': 1307664000},
#  'B0007PNAE6.AQ99D78W4ZIE8': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 5.0,
#   'reviewText': 'Great shows for the gym shower!  They drain and dry quickly.  And they keep you from slipping around.  They do at first feel a bit tough on the soles of the feet, but then it feels good.  All in, its a great product.',
#   'reviewTime': '05 16, 2013',
#   'reviewerID': 'AQ99D78W4ZIE8',
#   'reviewerName': 'Ray Smets',
#   'summary': 'Exactly what I wanted',
#   'unixReviewTime': 1368662400},
#  'B0007PNAE6.AOCJ3EQNNURB1': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 2.0,
#   'reviewText': 'I have seen others wear these slides and I know Adidas usually supplies an excellent product. I did read the other reviews that warned of a need for "breaking in" the sole nubs and wearing socks during that process. However, I\'ve worn these slides for 2+ months and they still make the soles of my feet tender unless I continue to wear socks.  I am disappointed in the slide but I will stubbornly continue to wear them. Maybe some day they will be "broken".',
#   'reviewTime': '01 9, 2007',
#   'reviewerID': 'AOCJ3EQNNURB1',
#   'reviewerName': 'Richard L. Edfeldt',
#   'summary': 'Unfulfilled expectations',
#   'unixReviewTime': 1168300800},
#  'B0007PNAE6.A1Y00RSEV8MA0N': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 1.0,
#   'reviewText': 'Being heavy the Santiossae treatment is not at all comfortable. I would recommend a smooth sole if you weigh more than normal.',
#   'reviewTime': '10 15, 2012',
#   'reviewerID': 'A1Y00RSEV8MA0N',
#   'reviewerName': 'RNDBY6',
#   'summary': 'Santiossage Slide',
#   'unixReviewTime': 1350259200},
#  'B0007PNAE6.A1SVNBZ91Y6DXU': {'asin': 'B0007PNAE6',
#   'helpful': [3, 8],
#   'overall': 1.0,
#   'reviewText': "The single most uncomfortable zhoe product I ever bought. Hard unyielding inner sole that doesn't massage just hurts. If you've nerver wore shoes before and went barefooted all you life you might like these.",
#   'reviewTime': '12 19, 2009',
#   'reviewerID': 'A1SVNBZ91Y6DXU',
#   'reviewerName': 'Robert A. Ciardi "rciardi"',
#   'summary': 'Self-Torture Appliance',
#   'unixReviewTime': 1261180800},
#  'B0007PNAE6.A3PI56S7L13MRT': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 3.0,
#   'reviewText': 'These sandals are difficult after a while. The little gel things really dig into your feet. I always wear socks with it.',
#   'reviewTime': '02 25, 2013',
#   'reviewerID': 'A3PI56S7L13MRT',
#   'reviewerName': 'Samantha Cardenas',
#   'summary': 'They are great but..',
#   'unixReviewTime': 1361750400},
#  'B0007PNAE6.A3VQFUAB6WQXMU': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 3.0,
#   'reviewText': 'not sure why i bought thought it would be cool but nubs really hurt they ended up in a free pile. not worth trying to send back or re sell. guess i made somebody else in the apartment complex happy though lol...',
#   'reviewTime': '02 19, 2014',
#   'reviewerID': 'A3VQFUAB6WQXMU',
#   'reviewerName': 'shovenose',
#   'summary': 'not recommended',
#   'unixReviewTime': 1392768000},
#  'B0007PNAE6.AI9LZBEN77WPX': {'asin': 'B0007PNAE6',
#   'helpful': [0, 0],
#   'overall': 4.0,
#   'reviewText': 'These shoes are what all the kids are wearing for all sporting activities. They are easy to slip on right after practice or a game and easy to clean if they get dirty but yet keep feet off locker room floors.',
#   'reviewTime': '03 27, 2014',
#   'reviewerID': 'AI9LZBEN77WPX',
#   'reviewerName': 'smd3',
#   'summary': 'Great for sports',
#   'unixReviewTime': 1395878400},
#  ...}
